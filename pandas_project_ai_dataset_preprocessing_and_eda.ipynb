# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/pandas-project-ai-dataset-preprocessing-eda?scriptVersionId=335090394" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# # 🐼 Pandas Project — AI Dataset Preprocessing & Exploratory Data Analysis
#
# >Learn how to preprocess and explore real-world data using ***Pandas***. This project covers data cleaning, handling missing values, feature engineering, exploratory data analysis (EDA), and visualization using the ***Titanic dataset*** to prepare data for future machine learning tasks.

# %% [markdown]
# ---
# # 📌 1. Introduction
#
# Data preprocessing and ***Exploratory Data Analysis (EDA)*** are fundamental steps in every data science and machine learning workflow. Before building any model, it is essential to understand the dataset, identify data quality issues, clean inconsistencies, and explore meaningful patterns.
#
# In this project, we will use the ***Titanic*** dataset to perform a complete preprocessing and EDA workflow using ***Pandas***. The notebook covers data exploration, handling missing values, removing duplicate records, feature engineering, statistical analysis, and data visualization.
#
# By the end of this project, the dataset will be ***clean, well-understood, and ready for machine learning***, while also revealing valuable insights into the factors that influenced passenger survival.
#
# <div align="center">
#     <img src="https://media.geeksforgeeks.org/wp-content/uploads/20260401165333112780/exploratory_data_analysis_eda_2.webp" width=500>
#     <img src="https://media.geeksforgeeks.org/wp-content/uploads/20260203154034613956/data_preprocessing.webp" width=500>
# </div>
#
# ## 🎯 Objectives
# 1. ***📥 Load and inspect the dataset***
# 2. ***🔍 Explore its structure and statistics***
# 3. ***🧹 Clean and preprocess the data***
# 4. ***⚙️ Perform feature engineering***
# 5. ***📊 Conduct Exploratory Data Analysis (EDA)***
# 6. ***📈 Visualize trends and relationships***
# 7. ***💡 Extract meaningful insights***
# 8. ***💾 Export the cleaned dataset***

# %% [markdown]
# ---
#
# # 📂 2. Import Libraries
#
# To perform ***data preprocessing***, ***analysis***, and ***visualization***, we first import the required Python libraries. Each library provides ***specialized tools*** that simplify working with datasets, from loading and cleaning data to generating ***informative visualizations.***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# # 📥 3. Load the Dataset
#
# The first step is to load the ***Titanic dataset*** into a `Pandas DataFrame`. Once loaded, we can begin ***exploring*** its structure, examine the available features, and prepare it for ***preprocessing*** and ***exploratory data analysis.***

# %%
df = pd.read_csv("/kaggle/input/datasets/yasserh/titanic-dataset/Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ---
#
# # 👀 4. Dataset Overview
# Before cleaning or analyzing the data, it's important to understand the ***dataset's structure*** and ***contents.*** This section provides a ***quick overview*** of the dataset, helping us identify its ***size***, ***features***, ***data types***, and ***basic statistical characteristics***.
#
# ## 4.1 Display First & Last Rows
# View the ***first*** and ***last*** few records of the dataset to get a ***quick understanding*** of its structure, values, and overall format.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## 4.2 Dataset Shape
# Determine the ***number of rows and columns*** to understand the ***size and dimensions*** of the dataset.

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# This shows that `df` has ***891 rows*** and ***12 columns***

# %% [markdown]
# ## 4.3 Column Names
#
# Display all ***column names*** to identify the ***available features*** and understand what information the dataset contains.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 4.4 Data Types
#
# Examine the ***data type*** of each column to distinguish between ***numerical, categorical, and text-based*** features, ensuring they are suitable for analysis.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 4.5 Dataset Information
#
# Get a ***comprehensive summary*** of the dataset, including the total ***number of entries***, ***non-null*** values, ***memory usage***, and ***data types*** for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 4.6 Statistical Summary
#
# Generate ***descriptive statistics*** for numerical features, including ***count***, ***mean***, ***standard deviation***, ***minimum***, ***maximum***, and ***quartile values,*** to better understand the data distribution.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ---
#
# # 🔎 5. Initial Data Exploration
# Before cleaning the dataset, it's important to perform an ***initial exploration*** to assess its overall quality and identify potential issues. This step helps us understand the ***completeness***, ***uniqueness***, and ***structure of the data***, allowing us to make informed preprocessing decisions.
#
# ## 5.1 Check Missing Values
# Identify columns that contain missing (`NaN`) values and determine how much data is missing in each. This helps decide whether to ***fill***, ***remove***, or ***retain missing entries*** during preprocessing.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# This shows that `Age` column has ***177***, `Cabin` column has ***687***, and `Embarked` column has ***2*** `NaN` values.

# %% [markdown]
# ## 5.2 Check Duplicate Records
# Detect duplicate rows that may introduce ***bias*** or ***redundancy*** into the analysis. Removing unnecessary duplicates helps improve ***data quality*** and ensures more ***reliable results***.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Here `0` shows that no ***row*** is repeated.

# %% [markdown]
# ## 5.3 Unique Values per Column
# Examine the number of unique values in ***each column*** to better understand the ***dataset's diversity***, ***identify categorical features***, and spot any unusual or ***inconsistent values***.

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ## 5.4 Memory Usage
# Measure the amount of memory consumed by the dataset. This is particularly ***useful*** when working with ***large datasets***, as it helps ***optimize memory usage*** and ***improve processing efficiency***.

# %%
df.memory_usage()
# Out:
# Index           132
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# dtype: int64

# %% [markdown]
# This is seperate memory taken by ***each column***. However, the ***total memory*** taken by `df` is:

# %%
df.memory_usage().sum()
# Out:
# np.int64(85668)

# %% [markdown]
# ---
# # 🧹 6. Data Cleaning
#
# Raw datasets often contain ***inconsistencies*** such as missing values, duplicate records, or incorrect data types. In this section, we ***clean*** and ***prepare*** the dataset to ensure it is ***accurate***, ***consistent***, and ready for analysis.
#
# ## 6.1 Handle Missing Values
#
# Missing values can ***affect the quality*** of analysis and machine learning models. Here, we identify missing data and apply ***appropriate techniques*** to handle it while preserving the ***integrity*** of the dataset.

# %%
df.Age = df.Age.fillna(df.Age.median())

# %% [markdown]
# > **We use the median for the `Age` column because it is less affected by outliers and provides a more reliable estimate than the mean.**

# %%
df.Cabin = df.Cabin.fillna("Unknown")

# %% [markdown]
# > **Since the `Cabin` column contains a large number of missing values, we replace them with `"Unknown"` (or drop the column) instead of using the mode to avoid introducing bias.**

# %%
df.Embarked = df.Embarked.fillna(df.Embarked.mode()[0])

# %% [markdown]
# > We use the **mode** for the `Embarked` column because it is **categorical data**, and the mode preserves the most frequently occurring category.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Now the data is fully ***inconsistent*** and has no `NaN` values.

# %% [markdown]
# ## 6.2 Fix Data Types
# Datasets may contain columns with ***incorrect data types***, such as numbers stored as text or dates stored as strings. We convert them to ***appropriate data types*** to enable accurate computations and analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# From this we can see that data types are ***already*** appropriate.

# %% [markdown]
# ## 6.3 Rename Columns
# Clear and consistent column names ***improve readability*** and make the dataset easier to work with. ***If necessary***, we rename columns using ***meaningful and standardized*** names.

# %%
df.rename(columns={
     "PassengerId": "Passenger_ID",
    "Pclass": "Passenger_Class",
    "SibSp": "Siblings_Spouses",
    "Parch": "Parents_Children",
    "Sex": "Gender"
}, inplace=True)
df
# Out:
#      Passenger_ID  Survived  Passenger_Class  \
# 0               1         0                3
# 1               2         1                1
# 2               3         1                3
# 3               4         1                1
# 4               5         0                3
# ..            ...       ...              ...
# 886           887         0                2
# 887           888         1                1
# 888           889         0                3
# 889           890         1                1
# 890           891         0                3
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# Now the data is fully ***cleaned***.

# %% [markdown]
# ---
# # ⚙️ 7. Feature Engineering
#
# ## 7.1 Create New Features
# Feature engineering involves creating ***new variables*** from existing data to uncover additional information. These new features can ***improve data analysis*** and often ***enhance the performance*** of future machine learning models.
#
# A passenger's ***family size*** is calculated using:

# %%
df["Family_Size"] = df["Siblings_Spouses"] + df["Parents_Children"] + 1
df
# Out:
#      Passenger_ID  Survived  Passenger_Class  \
# 0               1         0                3
# 1               2         1                1
# 2               3         1                3
# 3               4         1                1
# 4               5         0                3
# ..            ...       ...              ...
# 886           887         0                2
# 887           888         1                1
# 888           889         0                3
# 889           890         1                1
# 890           891         0                3
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# Checking whether passenger ***is alone*** or not:

# %%
df["Is_Alone"] = (df["Family_Size"]==1).astype(int)
df.head()
# Out:
#    Passenger_ID  Survived  Passenger_Class  \
# 0             1         0                3
# 1             2         1                1
# 2             3         1                3
# 3             4         1                1
# 4             5         0                3
#
#                                                 Name  Gender   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Siblings_Spouses  Parents_Children            Ticket     Fare    Cabin  \
# 0                 1                 0         A/5 21171   7.2500  Unknown
# 1                 1                 0          PC 17599  71.2833      C85
# ...

# %% [markdown]
# ## 7.2 Categorize Age Groups
# Instead of working with individual ages, we group passengers into meaningful ***age categories*** (such as Child, Teen, Adult, and Senior). This makes the data ***easier to analyze*** and helps identify treds across differnt age groups.

# %%
bins=[0, 12, 19, 35, 60, 100]
labels=["Child", "Teen", "Adult", "Middle Aged", "Senior"]

df["Age_Group"] = pd.cut(df.Age, bins=bins, labels=labels)
df
# Out:
#      Passenger_ID  Survived  Passenger_Class  \
# 0               1         0                3
# 1               2         1                1
# 2               3         1                3
# 3               4         1                1
# 4               5         0                3
# ..            ...       ...              ...
# 886           887         0                2
# 887           888         1                1
# 888           889         0                3
# 889           890         1                1
# 890           891         0                3
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# ## 7.3 Extract Passenger Titles from Name
#
# Passenger names contain titles such as ***Mr., Mrs., Miss., Master,*** and others. Extracting these titles provides ***additional demographic information*** that can reveal social patterns and serve as a valuable feature for analysis and machine learning.

# %%
df["Title"] = df.Name.str.extract(r",\s*([^\.]+)\.")
df
# Out:
#      Passenger_ID  Survived  Passenger_Class  \
# 0               1         0                3
# 1               2         1                1
# 2               3         1                3
# 3               4         1                1
# 4               5         0                3
# ..            ...       ...              ...
# 886           887         0                2
# 887           888         1                1
# 888           889         0                3
# 889           890         1                1
# 890           891         0                3
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# ---
# # 📊 8. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) helps us understand the dataset by ***uncovering patterns, trends, and relationships*** between variables. Through ***statistical summaries and visualizations***, we can gain meaningful insights that support better decision-making and prepare the data for future machine learning tasks.
#
# ## 8.1 Survival Analysis
#
# Analyze ***the factors*** that influenced passenger survival on the Titanic by ***comparing survival rates*** across different groups and identifying key patterns.
#
# ### 8.1.1 Overall Survival Rate
# Examine the percentage of passengers who survived versus those who did not.

# %%
per_survived = df.Survived.value_counts(normalize=True) * 100
per_survived
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
per_survived.index = ["Not Survived", "Survived"]
per_survived.plot.bar(
     xlabel="Survival Status",
     ylabel="Percentage (%)",
     title="Overall Survival Rate"
)
# Out:
# <Axes: title={'center': 'Overall Survival Rate'}, xlabel='Survival Status', ylabel='Percentage (%)'>

# %% [markdown]
# ### 8.1.2 Survival by Gender
# Compare survival rates between male and female passengers.

# %%
gen_survived = (
    df.groupby("Gender").Survived
      .value_counts()
      .unstack()
)

gen_survived.columns = ["Did Not Survive", "Survived"]

gen_survived.plot.bar(
    title="Passenger Survival Count by Gender",
    xlabel="Gender",
    ylabel="Number of Passengers",
)
# Out:
# <Axes: title={'center': 'Passenger Survival Count by Gender'}, xlabel='Gender', ylabel='Number of Passengers'>

# %% [markdown]
# ### 8.1.3 Survival by Passenger Class
# Investigate how ticket class affected the likelihood of survival.

# %%
pclass_survived = (df.groupby("Passenger_Class").Survived.value_counts().unstack())

pclass_survived.columns = ["Did Not Survive", "Survived"]

pclass_survived.plot.bar(
    title="Passenger Survival Count by Class",
    xlabel="Class",
    ylabel="Number of Passengers",
)
# Out:
# <Axes: title={'center': 'Passenger Survival Count by Class'}, xlabel='Class', ylabel='Number of Passengers'>

# %% [markdown]
# ### 8.1.4 Survival by Age Group
# Analyze survival trends across different age categories.

# %%
age_survived = (df.groupby("Age_Group").Survived.value_counts().unstack())

age_survived.columns = ["Did Not Survive", "Survived"]

age_survived.plot.bar(
    title="Passenger Survival Count by Age Group",
    xlabel="Age Group",
    ylabel="Number of Passengers",
)
# Out:
# /tmp/ipykernel_16/2042189922.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survived = (df.groupby("Age_Group").Survived.value_counts().unstack())
# <Axes: title={'center': 'Passenger Survival Count by Age Group'}, xlabel='Age Group', ylabel='Number of Passengers'>

# %% [markdown]
# ### 8.1.5 Survival by Embarkation Port
# Explore whether the port where passengers boarded influenced survival outcomes.

# %%
emb_survived = (df.groupby("Embarked").Survived.value_counts().unstack())

emb_survived.columns = ["Did Not Survive", "Survived"]

emb_survived.plot.bar(
    title="Passenger Survival Count by Embarkation Port",
    xlabel="Embarkation Port",
    ylabel="Number of Passengers",
)
# Out:
# <Axes: title={'center': 'Passenger Survival Count by Embarkation Port'}, xlabel='Embarkation Port', ylabel='Number of Passengers'>

# %% [markdown]
# ## 8.2 Passenger Demographics
# Understand the composition of the passengers by examining their ***demographic characteristics*** and ***overall distribution.***
#
# ### 8.2.1 Age Distribution
# Visualize how passenger ages are distributed across the dataset.

# %%
des = df.Age.describe()
des
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Age"].plot.hist(
    bins=20,
    title="Age Distribution",
    xlabel="Age",
    ylabel="Frequency"
)
# Out:
# <Axes: title={'center': 'Age Distribution'}, xlabel='Age', ylabel='Frequency'>

# %%
df["Age"].plot.kde(
    title="Age Density Distribution",
    xlabel="Age"
)
# Out:
# <Axes: title={'center': 'Age Density Distribution'}, ylabel='Density'>

# %% [markdown]
# ### 8.2.2 Gender Distribution
# Analyze the proportion of male and female passengers.

# %%
gen_des = df.Gender.value_counts()

gen_des.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 8.2.3 Passenger Class Distribution
# Examine the number of passengers traveling in each ticket class.

# %%
class_des = df.Passenger_Class.value_counts()

class_des.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 8.2.4 Family Size Distribution
# Explore how family sizes varied among passengers.

# %%
fam_des = df.Family_Size.value_counts().sort_index()

fam_des.plot.bar()
# Out:
# <Axes: xlabel='Family_Size'>

# %% [markdown]
# ## 8.3 Fare Analysis
#
# Analyze ticket fares to understand ***pricing patterns*** and their relationship with passenger characteristics and survival.
#
# ### 8.3.1 Fare Distribution
# Examine how ticket fares are distributed across all passengers.

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df.Fare.plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 8.3.2 Fare by Passenger Class
# Compare fare distributions among different passenger classes.

# %%
pclass_fare = df.groupby("Passenger_Class").Fare.mean()
pclass_fare.plot.bar()
# Out:
# <Axes: xlabel='Passenger_Class'>

# %% [markdown]
# ## 8.4 Relationship Analysis
# Study relationships between ***numerical features*** to identify correlations and ***potential patterns*** within the dataset.
#
# Visualize ***correlations*** between numerical variables using a ***heatmap***.

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # 💡 9. Key Insights
#
# ## 🚢 Survival Patterns
# - The overall survival rate was **approximately 38%**, meaning the majority of passengers did not survive.
# - **Female passengers** had a significantly higher survival rate than male passengers.
# - **First-class passengers** were considerably more likely to survive than those in second and third class.
# - **Children** generally had better survival chances than adults.
#
#
# ## 💰 Passenger Characteristics
# - Higher ticket fares were generally associated with higher survival rates.
# - Passengers traveling with **small families** tended to have better survival outcomes than those traveling alone or in very large groups.
# - Survival rates varied across different **embarkation ports**, although the differences were less pronounced.
#
#
# ## 🧹 Data Quality
# - The dataset contained missing values, primarily in the **Age**, **Cabin**, and **Embarked** columns.
# - Data preprocessing, including handling missing values and feature engineering, improved the dataset's quality for analysis.

# %% [markdown]
# ---
# # 💾 10. Export the Cleaned Dataset
#
# After completing data cleaning, preprocessing, and feature engineering, the final step is to ***save*** the processed dataset. Exporting the cleaned data allows it to be ***reused*** for future machine learning projects ***without repeating*** the preprocessing workflow.

# %%
df.to_csv("cleaned_dataset.csv")

# %% [markdown]
# ---
#
# ## ✅ 12. Conclusion
#
# The analysis indicates that **gender, passenger class, age, and fare** were the most influential factors affecting passenger survival. After preprocessing and exploratory data analysis, the dataset is clean, well-understood, and ready for future machine learning tasks.
#
# ---
#
# ## ❤️ Support
#
# If you found this notebook helpful, consider **upvoting ⭐** it and sharing your feedback. Contributions and suggestions are always welcome!
#
# ---
# ---
