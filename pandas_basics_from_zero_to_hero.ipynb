# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/pandas-01-series-dataframes-csv?scriptVersionId=324537184" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # 🐼📈 Pandas Toolkit: Series, DataFrames & Filters
#
# ---
#
# ## 📖 Introduction
#
# **Pandas** is one of the most popular Python libraries for **data analysis** and **data manipulation**. It provides powerful and easy-to-use data structures such as **Series** and **DataFrames**, allowing us to efficiently organize, explore, filter, and transform data.
#
# In this notebook, we will build a solid understanding of Pandas by exploring its core features step by step. From creating and working with **Series** and **DataFrames** to performing **indexing**, **conditional selection**, and **file operations**, this notebook covers the essential concepts required for effective data analysis.
#
# ## 🎯 Topics Covered
#
# - 🐼 **Level 1:** Introduction to Pandas
# - 📊 **Level 2:** Getting Started — DataFrames & Exploration
# - 📘 **Level 3:** Pandas Series — Working with 1D Data
# - 📝 **Level 4:** Intermediate Pandas Series — Series Indexing
# - 📑 **Level 6:** Python DataFrames — Mastering Tabular Data (2D Structure)
# - 💡 **Level 7:** DataFrame Operations — Managing Columns
# - 🔍 **Level 8:** DataFrame Indexing — Selecting Specific Data
# - 🎯 **Level 9:** DataFrame Conditional Selection — Isolating Targets
# - 💾 **Level 10:** Writing and Viewing Data — Input/Output
# - 📈 **Level 11:** Data Analysis — Aggregation & Statistics

# %% [markdown]
# ---
#
# # 🐼 Level 1: Introduction to Pandas
#
# Welcome to the **Pandas Learning Series ⚡**
#
# **Pandas** is a powerful Python library for working with structured data 📊 using **DataFrames** and **Series**. It helps in cleaning 🧹, analyzing 🔍, and preparing data for machine learning 🤖, and works well with NumPy and Matplotlib.
#
# <div align=center>
#
# <img src="https://images.decodo.com/Python_Pandas_1_cc44acf7dc/Python_Pandas_1_cc44acf7dc.png" width=700 />
#
# </div>
#
# ### Key Uses of Pandas:
#
# * **Data Analysis** 📈 — Find patterns and insights in data
# * **Data Cleaning** 🧹 — Fix/remove missing or incorrect data
# * **Data Exploration** 🔍 — Understand dataset structure and relationships
#
# <div align=center>
#
# <img src="https://www.datocms-assets.com/14946/1742484633-6683f897b1383d93497fbd5d_ad_4nxf2tnvvb852lmvmziifuwaczkerckindzqcdeawdxod5ebfs9zenxqd4e6vkck6jhfrs5whlredngeze6wvypv-fxjrwijc5pk3tj6ek3nw4vsi-t7zynb0tszajpbpf6q4jfmez8iz-gil7d5y1nfyemda.png" width=600 />
#
# </div>
#
# ## 1.1 Why Use Pandas? 📊
#
# Pandas is essential for handling **large, messy, real-world datasets** efficiently.
#
# ### Big Data 🌐
#
# Big Data means datasets that are:
#
# * 📦 Too large
# * 🧩 Too complex
#   for traditional tools.
#
# ### Data Science Role 🧠
#
# Data Science is about collecting, organizing, and analyzing data to extract useful insights — and Pandas is a core tool for that.
#
# ### Data vs Information 🔄
#
# * **Data:** Raw facts
# * **Information:** Processed, meaningful data
#
# 👉 **Pandas helps turn data into useful information.**
#
# <div align=center>
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*hPC7fpV0kAa-Z7xH4_-2BQ.png" width=600 />
#
# </div>
#
#
# ## 1.2 What Can Pandas Do? 🐼
#
# Pandas helps you perform common data operations easily:
#
#
# <img src="https://img.shields.io/badge/Find%20Correlation-0EA5E9?style=for-the-badge" /> Understand relationships between columns/features (how one variable changes with another).
#
# <img src="https://img.shields.io/badge/Calculate%20Average-6366F1?style=for-the-badge" /> Find mean values of data.
#
# <img src="https://img.shields.io/badge/Find%20Min%20&%20Max-22C55E?style=for-the-badge" /> Get smallest and largest values in a dataset.
#
# <img src="https://img.shields.io/badge/Handle%20Missing%20Data-F59E0B?style=for-the-badge" /> Remove or fix null/missing values.
#
# <img src="https://img.shields.io/badge/Organize%20Data-E11D48?style=for-the-badge" /> Sort, filter, and reshape datasets efficiently.
#
# 👉 In short: **Pandas makes data analysis faster and easier.**

# %% [markdown]
# ---
#
# # 📊 Level 2: Getting Started — DataFrames & Exploration
#
# ## 2.1 Imorting Pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2.2 Checking version

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## 2.3 Creating DataFrame
#
# We will discuss data frame in detail later, right now we will only see what is difference between data frame and dictionary

# %%
dataset1 = {
    "cars":["BMW", "Mercedes", "Rolls Royace"],
    "value":[1, 2, 3]
}
print(f"\nThis is basic Python dictionary:\n{dataset1}")
data_frame1 = pd.DataFrame(dataset1)
print(f"\nThis is data frame:\n{data_frame1}")
# Out:
# This is basic Python dictionary:
# {'cars': ['BMW', 'Mercedes', 'Rolls Royace'], 'value': [1, 2, 3]}
#
# This is data frame:
#            cars  value
# 0           BMW      1
# 1      Mercedes      2
# 2  Rolls Royace      3

# %% [markdown]
# ---
#
# # 📘 Level 3: Pandas Series — Working with 1D Data
#
# <div align="center">
#     <img src="https://www.scaler.com/topics/images/pandas-series-thumbnail.webp" width=600>
# </div>
#
# ## 3.1 What is Series?
# Pandas Series is like a column iin a table, it is a one-dimensional array containing data of any type.
#
# ## 3.2 Conversion: LIST -> SERIES

# %%
list1 = [10, 20, 30, 40, 50]
series1 = pd.Series(list1)
print(f"\nPandas series looks like this:\n{series1}")
# Out:
# Pandas series looks like this:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ## 3.3 Conversion: NUMPY ARRAY -> SERIES

# %%
import numpy as np

array1 = np.array([100, 200, 300, 400, 500])
series2 = pd.Series(array1)
print(f"\nPandas series looks like this:\n{series2}")
# Out:
# Pandas series looks like this:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %% [markdown]
# ## 3.4 Python List VS Pandas Series
#
# | Feature        | List 🐍         | Series 🐼           |
# | -------------- | --------------- | ------------------- |
# | **Type**       | Python built-in | Pandas object       |
# | **Index**      | Numeric only    | Custom or numeric   |
# | **Operations** | Basic           | Advanced/vectorized |
# | **Use**        | General purpose | Data analysis       |
#
# 👉 **List = simple container**
# 👉 **Series = labeled smart list** 🚀

# %% [markdown]
# ## 3.5 Conversion: DICTIONARY -> SERIES

# %%
dictionary1 = {
    "a": "Earth",
    "b": "Mars",
    "c": "Jupiter",
    "d": "Saturn"
}

series3 = pd.Series(dictionary1)
print(f"\nPython Dictionary to Pandas series:\n{series3}")
# Out:
# Python Dictionary to Pandas series:
# a      Earth
# b       Mars
# c    Jupiter
# d     Saturn
# dtype: object

# %% [markdown]
# ---
#
# # 📝 Level 4: Intermediate Pandas Series — Series Indexing
#
# ## 4.1 Series from Label Lists
# Our task is to take the data and label values as seperated lists and create Pandas Series

# %%
labels = ["car1", "car2", "car3"]
cars = ["Honda", "Toyota", "BYD"]

car_series = pd.Series(data=cars, index=labels)
print(f"\nSeries with labels:\n{car_series}")
# Out:
# Series with labels:
# car1     Honda
# car2    Toyota
# car3       BYD
# dtype: object

# %% [markdown]
# ## 4.2 Accessing items in Pandas Series
# We can access an element of Pandas Series by indexing it's label/index

# %%
print(f"\nFirst element of `car_series`:\n{car_series["car1"]}")
print(f"\nSecond element of `car_series`:\n{car_series["car2"]}")
print(f"\nThird element of `car_series`:\n{car_series["car3"]}")
# Out:
# First element of `car_series`:
# Honda
#
# Second element of `car_series`:
# Toyota
#
# Third element of `car_series`:
# BYD

# %% [markdown]
# ---
#
# # 🔢 Level 5: Advanced Pandas Series — Series Operations
#
# ## 5.1 Pandas Series Addition
# Pandas Series addition is element-wise addition based on matching labels.

# %%
ser1 = pd.Series([50, 100, 150, 200], ["a", "b", "c", "d"])
ser2 = pd.Series([250, 300, 350, 400], ["b", "c", "d", "e"])

ser1 + ser2
# Out:
# a      NaN
# b    350.0
# c    450.0
# d    550.0
# e      NaN
# dtype: float64

# %% [markdown]
# ## 5.2 Addition using add() method

# %%
print(f"\nWith using add():\n{ser1.add(ser2)}")
# Out:
# With using add():
# a      NaN
# b    350.0
# c    450.0
# d    550.0
# e      NaN
# dtype: float64

# %% [markdown]
# When we use simple add() the result is same as direct addition, if we want to retain values of labels that does not match we can do like this:

# %%
print(f"\nWith using `fill_value` argument:\n{ser1.add(ser2, fill_value=0)}")
# Out:
# With using `fill_value` argument:
# a     50.0
# b    350.0
# c    450.0
# d    550.0
# e    400.0
# dtype: float64

# %% [markdown]
# ## 5.3 Subtraction using sub() method

# %%
print(f"\nUsing `fill_value` argument while subtracting:\n{ser2.sub(ser1, fill_value=0)}")
# Out:
# Using `fill_value` argument while subtracting:
# a    -50.0
# b    150.0
# c    150.0
# d    150.0
# e    400.0
# dtype: float64

# %% [markdown]
# ---
#
# # 📑 Level 6: Python DataFrames — Mastering Tabular Data (2D Structure)
#
# <div align="center">
#     <img src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/creating_dataframe1.png" width=600 />
# </div>
#
# A **DataFrame** is a **2-dimensional data structure in Pandas** used to store and organize data in a tabular format with **rows and columns**, where each column can have a different data type.
#
# * DataFrames are the workhouse of Pandas
# * They are directly inspired by R Programming Language
# * We can think of it as bunch of Series objects put together

# %% [markdown]
# ## 6.1 Creating a DataFrame

# %%
df = pd.DataFrame(
    np.random.rand(5, 6),
    index="A B C D E".split(),
    columns="U V W X Y Z".split()
)
df
# Out:
#           U         V         W         X         Y         Z
# A  0.267188  0.610531  0.985822  0.138664  0.281416  0.263505
# B  0.757699  0.854414  0.840428  0.993011  0.379431  0.359019
# C  0.394339  0.428829  0.038453  0.792877  0.664098  0.531987
# D  0.256231  0.608440  0.552268  0.946803  0.324620  0.278629
# E  0.741551  0.437568  0.846092  0.471065  0.325017  0.127368

# %% [markdown]
# ## 6.2 Accessing row and column of DataFrame
#
# ### Accessing Row

# %%
"""We cannot access row like this so later we will use loc and iloc to access row"""
# df["A"]
# This couses an error
# Out:
# 'We cannot access row like this so later we will use loc and iloc to access row'

# %% [markdown]
# ### Accessing Column

# %%
"""But we can access column directly like this"""
df["X"]
# Out:
# A    0.138664
# B    0.993011
# C    0.792877
# D    0.946803
# E    0.471065
# Name: X, dtype: float64

# %% [markdown]
# ## 6.3 Accessing multiple columns
# To access multiple columns we can pass a list of columns

# %%
df[["X", "Y"]]
# Please note that we have to pass `list` of columns not just columns
# Out:
#           X         Y
# A  0.138664  0.281416
# B  0.993011  0.379431
# C  0.792877  0.664098
# D  0.946803  0.324620
# E  0.471065  0.325017

# %% [markdown]
# ## 6.4 Proof: DataFrame is bunch of Series
#
# <div align="center">
#     <img src="https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png" width=600 />
# </div>

# %%
type(df["W"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# So each column is a **Series**.
#
# Meaning:
#
# * **A DataFrame = multiple Series aligned together by index**

# %% [markdown]
# ---
#
# # 💡 Level 7: DataFrame Operations — Managing Columns
#
# Explore how to **create, modify, and delete** columns in Pandas **DataFrames** to keep your data structured, flexible, and ready for analysis.

# %% [markdown]
# ## 7.1 Creating DataFrame

# %%
data = pd.DataFrame(np.random.randn(4,6), columns=["A", "B", "C", "D", "E", "F"])
data
# Out:
#           A         B         C         D         E         F
# 0  0.083226 -0.042931  0.972047 -0.665268 -0.224099  0.943140
# 1 -0.800156 -1.769195  0.056952 -1.882754 -0.673084  1.998357
# 2  1.525165 -0.526773 -0.061140  0.936332 -1.104896 -0.322619
# 3 -1.242508 -2.583634  0.695026 -0.407505  1.649248  0.148080

# %% [markdown]
# ## 7.2 Adding Column

# %%
data["G"] = [10, 20, 30, 40]
data
# Out:
#           A         B         C         D         E         F   G
# 0  0.083226 -0.042931  0.972047 -0.665268 -0.224099  0.943140  10
# 1 -0.800156 -1.769195  0.056952 -1.882754 -0.673084  1.998357  20
# 2  1.525165 -0.526773 -0.061140  0.936332 -1.104896 -0.322619  30
# 3 -1.242508 -2.583634  0.695026 -0.407505  1.649248  0.148080  40

# %% [markdown]
# ## 7.2 Removing Column
# We can remove column by simply using **.drop()** method
#
# * **📌 Note:** Set the `axis` parameter to `1` when removing columns.

# %%
data.drop("A", axis=1)
# Out:
#           B         C         D         E         F   G
# 0 -0.042931  0.972047 -0.665268 -0.224099  0.943140  10
# 1 -1.769195  0.056952 -1.882754 -0.673084  1.998357  20
# 2 -0.526773 -0.061140  0.936332 -1.104896 -0.322619  30
# 3 -2.583634  0.695026 -0.407505  1.649248  0.148080  40

# %% [markdown]
# ⚠️ By default, `.drop()` does **not** permanently modify the original DataFrame unless `inplace=True` is used.

# %%
data.drop("A", axis=1, inplace=True)
data
# Out:
#           B         C         D         E         F   G
# 0 -0.042931  0.972047 -0.665268 -0.224099  0.943140  10
# 1 -1.769195  0.056952 -1.882754 -0.673084  1.998357  20
# 2 -0.526773 -0.061140  0.936332 -1.104896 -0.322619  30
# 3 -2.583634  0.695026 -0.407505  1.649248  0.148080  40

# %% [markdown]
# ---
#
# # 🔍 Level 8: DataFrame Indexing — Selecting Specific Data
#
# We will start by creting a random DataFrame of 2x2

# %%
randomData = pd.DataFrame(np.random.randint(100, 150, size=(3, 3)),
                          index=["2023 Sales", "2024 Sales", "2025 Sales"],
                          columns=["Product 1", "Product 2", "Product 3"])
randomData
# Out:
#             Product 1  Product 2  Product 3
# 2023 Sales        136        108        145
# 2024 Sales        145        148        118
# 2025 Sales        136        134        135

# %% [markdown]
# ## 8.1 Selecting Column
# We discussed earlier that we can access column directly as below

# %%
randomData["Product 1"]
# Out:
# 2023 Sales    136
# 2024 Sales    145
# 2025 Sales    136
# Name: Product 1, dtype: int64

# %% [markdown]
# ## 8.2 Selecting Row
# But we cannot select row **directly** from a DataFrame.
#
# There are 2 methods to access row:
# - **.loc[]** - uses label of row
# - **.iloc[]** - uses index of row
#
# ### 8.2.1. Using .loc()

# %%
# Using loc[] for aceesing sales across Years 2023, 2024, 2025
print(randomData.loc["2023 Sales"], "\n")
print(randomData.loc["2024 Sales"], "\n")
print(randomData.loc["2025 Sales"], "\n")
# Out:
# Product 1    136
# Product 2    108
# Product 3    145
# Name: 2023 Sales, dtype: int64
#
# Product 1    145
# Product 2    148
# Product 3    118
# Name: 2024 Sales, dtype: int64
#
# Product 1    136
# Product 2    134
# Product 3    135
# Name: 2025 Sales, dtype: int64

# %% [markdown]
# ### 8.2.2 Using .iloc()

# %%
# Using iloc[] for aceesing sales across Years 2023, 2024, 2025
print(randomData.iloc[0], "\n")
print(randomData.iloc[1], "\n")
print(randomData.iloc[2], "\n")
# Out:
# Product 1    136
# Product 2    108
# Product 3    145
# Name: 2023 Sales, dtype: int64
#
# Product 1    145
# Product 2    148
# Product 3    118
# Name: 2024 Sales, dtype: int64
#
# Product 1    136
# Product 2    134
# Product 3    135
# Name: 2025 Sales, dtype: int64

# %% [markdown]
# ## 8.3 Selecting Particular Value

# %%
# Column-first look up (Uses label names)
print(f"The Sales of product 1 in 2024 is: {randomData['Product 1']['2024 Sales']}")

# Label-based look up (df.loc[row_label, col_label])
print(f"Using loc[]: {randomData.loc["2024 Sales", "Product 1"]}")

# Position-based look up (df.iloc[row_index, col_index])
print(f"Using iloc[]: {randomData.iloc[1, 0]}")
# Out:
# The Sales of product 1 in 2024 is: 145
# Using loc[]: 145
# Using iloc[]: 145

# %% [markdown]
# ## 8.4 Selecting Subset of DataFrame

# %%
randomData.loc[["2023 Sales", "2024 Sales"], ["Product 2", "Product 3"]]
# Out:
#             Product 2  Product 3
# 2023 Sales        108        145
# 2024 Sales        148        118

# %% [markdown]
# ---
#
# # 🎯 Level 9: DataFrame Conditional Selection — Isolating Targets
# An important feature of Pandas is **Conditional Selection** using bracket notation which is **very similar** to NumPy

# %%
randPopulation = pd.DataFrame(np.random.randint(10000000, 550000000, size=(3, 3)),
                          index=["2023 Population", "2024 Population", "2025 Population"],
                          columns=["Country 1", "Country 2", "Country 3"])
randPopulation
# Out:
#                  Country 1  Country 2  Country 3
# 2023 Population   31028194  519853320  453227288
# 2024 Population  348189743  443181943  539080404
# 2025 Population  438580374   23418130  501087799

# %% [markdown]
# ## 9.1 Checking Population Conditions
#
# Here, we check which country populations are greater than **300,000,000**.
# The result will return **True** for matching values and **False** for non-matching values.

# %%
randPopulation > 300000000
# Out:
#                  Country 1  Country 2  Country 3
# 2023 Population      False       True       True
# 2024 Population       True       True       True
# 2025 Population       True      False       True

# %% [markdown]
# ## 9.2 Filtering Countries by Population
#
# Now, we use the condition to filter the DataFrame and display only the population values greater than **300,000,000**.

# %%
randPopulation[randPopulation > 300000000]
# Out:
#                    Country 1    Country 2  Country 3
# 2023 Population          NaN  519853320.0  453227288
# 2024 Population  348189743.0  443181943.0  539080404
# 2025 Population  438580374.0          NaN  501087799

# %% [markdown]
# ## 9.3 Filtering Rows with Conditions
#
# How to filter rows in a **DataFrame** using conditions.
# We check values inside a `column` and display only the rows that satisfy the **condition**.

# %%
randPopulation[randPopulation["Country 1"] > 300000000]
# Out:
#                  Country 1  Country 2  Country 3
# 2024 Population  348189743  443181943  539080404
# 2025 Population  438580374   23418130  501087799

# %% [markdown]
# ## 9.4 Filtering Rows & Selecting a Column
#
# Filter rows where `"Country 1"` population is greater than `300000000`, then display only the `"Country 1"` column.

# %%
randPopulation[randPopulation["Country 1"] > 300000000]["Country 1"]
# Out:
# 2024 Population    348189743
# 2025 Population    438580374
# Name: Country 1, dtype: int64

# %% [markdown]
# ---
#
# # 💾 Level 10: Writing and Viewing Data — Input/Output
#
# Quickly save your processed DataFrames to external files or inspect their contents directly in your notebook to verify your results.
#
# ### 🛠️ Key Operations
#
# * **Viewing:** Use `.head()` or `.tail()` to quickly peek at your data.
# * **Writing:** Use functions like `.to_csv()` or `.to_excel()` to export your work.

# %% [markdown]
# ## 10.1 Working with CSV Files
#
# Learn how to read, write, and manage data using **CSV files** in Pandas.

# %% [markdown]
# ### 10.1.1 Reading CSV File

# %%
iPhoneData = pd.read_csv("/kaggle/input/datasets/jawadaahmed/iphone-sales-analytics-dataset/iphone_sales_dataset.csv")
iPhoneData
# Out:
#     Order_ID Customer_Name  Country       iPhone_Model Storage   Color  \
# 0       1001    Customer_1      USA          iPhone 13   256GB  Purple
# 1       1002    Customer_2   Canada          iPhone 12   256GB    Blue
# 2       1003    Customer_3   Canada  iPhone 15 Pro Max   512GB   Black
# 3       1004    Customer_4      USA  iPhone 15 Pro Max   512GB   Black
# 4       1005    Customer_5      USA          iPhone 15   128GB    Blue
# ..       ...           ...      ...                ...     ...     ...
# 95      1096   Customer_96      UAE      iPhone 14 Pro   256GB    Blue
# 96      1097   Customer_97       UK  iPhone 15 Pro Max   512GB   White
# 97      1098   Customer_98       UK  iPhone 15 Pro Max   512GB   White
# 98      1099   Customer_99  Germany  iPhone 15 Pro Max   512GB  Purple
# 99      1100  Customer_100       UK          iPhone 15   512GB    Blue
#
#     Quantity  Price   Sale_Date Payment_Method
# 0          5   1817  2025-05-01     Debit Card
# ...

# %% [markdown]
# ### 10.1.2 Converting to string

# %%
print(iPhoneData.to_string())
# Out:
#     Order_ID Customer_Name   Country       iPhone_Model Storage   Color  Quantity  Price   Sale_Date Payment_Method
# 0       1001    Customer_1       USA          iPhone 13   256GB  Purple         5   1817  2025-05-01     Debit Card
# 1       1002    Customer_2    Canada          iPhone 12   256GB    Blue         1    998  2025-03-05         PayPal
# 2       1003    Customer_3    Canada  iPhone 15 Pro Max   512GB   Black         5    876  2025-01-25    Credit Card
# 3       1004    Customer_4       USA  iPhone 15 Pro Max   512GB   Black         2   1290  2025-03-24     Debit Card
# 4       1005    Customer_5       USA          iPhone 15   128GB    Blue         3   1092  2025-02-01     Debit Card
# 5       1006    Customer_6       UAE      iPhone 14 Pro   256GB     Red         5   1939  2025-02-15     Debit Card
# 6       1007    Customer_7   Germany      iPhone 14 Pro   512GB    Blue         1   1798  2025-02-13     Debit Card
# ...

# %% [markdown]
# ### 10.1.3 Accessing first 5 entries

# %%
iPhoneData.head()
# Out:
#    Order_ID Customer_Name Country       iPhone_Model Storage   Color  \
# 0      1001    Customer_1     USA          iPhone 13   256GB  Purple
# 1      1002    Customer_2  Canada          iPhone 12   256GB    Blue
# 2      1003    Customer_3  Canada  iPhone 15 Pro Max   512GB   Black
# 3      1004    Customer_4     USA  iPhone 15 Pro Max   512GB   Black
# 4      1005    Customer_5     USA          iPhone 15   128GB    Blue
#
#    Quantity  Price   Sale_Date Payment_Method
# 0         5   1817  2025-05-01     Debit Card
# 1         1    998  2025-03-05         PayPal
# 2         5    876  2025-01-25    Credit Card
# 3         2   1290  2025-03-24     Debit Card
# 4         3   1092  2025-02-01     Debit Card

# %% [markdown]
# ### 10.1.4 Accessing last five entires

# %%
iPhoneData.tail()
# Out:
#     Order_ID Customer_Name  Country       iPhone_Model Storage   Color  \
# 95      1096   Customer_96      UAE      iPhone 14 Pro   256GB    Blue
# 96      1097   Customer_97       UK  iPhone 15 Pro Max   512GB   White
# 97      1098   Customer_98       UK  iPhone 15 Pro Max   512GB   White
# 98      1099   Customer_99  Germany  iPhone 15 Pro Max   512GB  Purple
# 99      1100  Customer_100       UK          iPhone 15   512GB    Blue
#
#     Quantity  Price   Sale_Date Payment_Method
# 95         1   1743  2025-03-09    Credit Card
# 96         3   1671  2025-02-08    Credit Card
# 97         4   1125  2025-01-08     Debit Card
# 98         5   1540  2025-02-04     Debit Card
# 99         3   1549  2025-03-28     Debit Card

# %% [markdown]
# ### 10.1.5 Viewing DataFrame Information
#
# Use `iPhoneData.info()` to display a summary of the **DataFrame**, including column names, data types, non-null values, and memory usage.

# %%
iPhoneData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        100 non-null    int64
#  1   Customer_Name   100 non-null    object
#  2   Country         100 non-null    object
#  3   iPhone_Model    100 non-null    object
#  4   Storage         100 non-null    object
#  5   Color           100 non-null    object
#  6   Quantity        100 non-null    int64
#  7   Price           100 non-null    int64
#  8   Sale_Date       100 non-null    object
#  9   Payment_Method  100 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 7.9+ KB

# %% [markdown]
# ### 10.1.6 Viewing DataFrame Column Names
#
# We use `.keys()` to display all the **column labels** present in the DataFrame.

# %%
iPhoneData.keys()
# Out:
# Index(['Order_ID', 'Customer_Name', 'Country', 'iPhone_Model', 'Storage',
#        'Color', 'Quantity', 'Price', 'Sale_Date', 'Payment_Method'],
#       dtype='object')

# %% [markdown]
# ### 10.1.7 Previewing the First & Last Rows
#
# Use `iPhoneData.head(15)` and `iPhoneData.tail(15)` to display the first and last **15 rows** of the DataFrame for quick data inspection.

# %%
iPhoneData.head(15)
# Out:
#     Order_ID Customer_Name   Country       iPhone_Model Storage   Color  \
# 0       1001    Customer_1       USA          iPhone 13   256GB  Purple
# 1       1002    Customer_2    Canada          iPhone 12   256GB    Blue
# 2       1003    Customer_3    Canada  iPhone 15 Pro Max   512GB   Black
# 3       1004    Customer_4       USA  iPhone 15 Pro Max   512GB   Black
# 4       1005    Customer_5       USA          iPhone 15   128GB    Blue
# 5       1006    Customer_6       UAE      iPhone 14 Pro   256GB     Red
# 6       1007    Customer_7   Germany      iPhone 14 Pro   512GB    Blue
# 7       1008    Customer_8        UK  iPhone 15 Pro Max   128GB  Purple
# 8       1009    Customer_9       UAE          iPhone 12   512GB  Purple
# 9       1010   Customer_10  Pakistan      iPhone 14 Pro   128GB     Red
# 10      1011   Customer_11        UK  iPhone 15 Pro Max   256GB   White
# 11      1012   Customer_12       USA          iPhone 14   128GB   Black
# ...

# %%
iPhoneData.tail(15)
# Out:
#     Order_ID Customer_Name  Country       iPhone_Model Storage   Color  \
# 85      1086   Customer_86  Germany          iPhone 12   256GB   Black
# 86      1087   Customer_87   Canada          iPhone 15   128GB   White
# 87      1088   Customer_88       UK  iPhone 15 Pro Max   512GB  Purple
# 88      1089   Customer_89      USA          iPhone 13   256GB   White
# 89      1090   Customer_90      USA          iPhone 12   256GB   White
# 90      1091   Customer_91      UAE          iPhone 15   256GB     Red
# 91      1092   Customer_92      UAE  iPhone 15 Pro Max   256GB   White
# 92      1093   Customer_93       UK          iPhone 12   256GB   Black
# 93      1094   Customer_94      USA  iPhone 15 Pro Max   512GB   White
# 94      1095   Customer_95   Canada          iPhone 13   128GB   White
# 95      1096   Customer_96      UAE      iPhone 14 Pro   256GB    Blue
# 96      1097   Customer_97       UK  iPhone 15 Pro Max   512GB   White
# ...

# %% [markdown]
# ---
#
# # 📈 Level 11: Data Analysis — Aggregation & Statistics
#
# In this level, we dive into data analysis using Pandas aggregation and statistical functions. Through summaries, calculations, and descriptive statistics, we uncover meaningful patterns and insights hidden within the data, transforming raw information into valuable knowledge.

# %%
image_stats = pd.read_csv("/kaggle/input/datasets/ahmedfakhar123/image-processing-samples/image_analysis_summary.csv")
image_stats
# Out:
#           File Name                     Primary Object/Topic  Width (px)  \
# 0       Smartphones            Smartphones (Multiple brands)         592
# 1            Laptop                HP Laptop (Windows 11 OS)         482
# 2  Forest landscape               Forest landscape at sunset         592
# 3       Pandas logo                      Pandas library logo         592
# 4   Matplotlib logo       Matplotlib library logo and charts         592
# 5     Mountain peak  Snow-covered mountain peak (Ama Dablam)         592
# 6        NumPy logo                       NumPy library logo         310
# 7        Motorcycle                 Suzuki sports motorcycle         544
# 8        Sports car         Futuristic sports car in a field         592
#
#    Height (px)                 Dominant Colors       Category File Format
# 0          411       Pink, Blue, Orange, White    Electronics         jpg
# 1          411             Silver, Black, Blue    Electronics         jpg
# ...

# %% [markdown]
# ## 11.1 Basic Aggregation Functions
# Using common aggregation methods to calculate summary statistics.

# %%
print(image_stats["Width (px)"].mean())
print(image_stats["Width (px)"].min())
print(image_stats["Width (px)"].max())
print(image_stats["Width (px)"].count())
# Out:
# 543.1111111111111
# 310
# 592
# 9

# %% [markdown]
# ## 11.2 Descriptive Statistics with `describe()`
# Generate a statistical summary of numerical columns.

# %%
image_stats.describe()
# Out:
#        Width (px)  Height (px)
# count    9.000000     9.000000
# mean   543.111111   325.444444
# std     95.142583    89.493172
# min    310.000000   140.000000
# 25%    544.000000   311.000000
# 50%    592.000000   333.000000
# 75%    592.000000   395.000000
# max    592.000000   411.000000

# %% [markdown]
# Provides:
# - Count
# - Mean
# - Standard Deviation
# - Minimum
# - Quartiles (25%, 50%, 75%)
# - Maximum

# %% [markdown]
# ## 11.3 Finding Largest and Smallest Values
# Identify top and bottom values in a dataset.

# %%
print(image_stats["Width (px)"].nlargest(2))
print(image_stats["Width (px)"].nsmallest(2))
# Out:
# 0    592
# 2    592
# Name: Width (px), dtype: int64
# 6    310
# 1    482
# Name: Width (px), dtype: int64

# %% [markdown]
# ## 11.4 Counting Unique Values
# Analyze the frequency of values in a column.

# %%
image_stats["Width (px)"].value_counts()
# Out:
# Width (px)
# 592    6
# 482    1
# 310    1
# 544    1
# Name: count, dtype: int64

# %% [markdown]
# Find the number of unique values:

# %%
image_stats["Width (px)"].nunique()
# Out:
# 4

# %% [markdown]
# ## 11.5 Calculating Statistical Measures
# Compute additional statistical metrics.

# %%
print(image_stats["Width (px)"].median())
print(image_stats["Width (px)"].std())
print(image_stats["Width (px)"].var())
# Out:
# 592.0
# 95.14258305885494
# 9052.11111111111

# %% [markdown]
# ---
#
# # 🎉 Conclusion
#
# In this notebook, we explored the core fundamentals of **Pandas** — one of the most powerful Python libraries for data analysis. From creating **Series** and **DataFrames** to performing indexing, filtering, column operations, and file handling, each section built practical skills for working with structured data efficiently.
#
# By completing these levels, you now understand how to:
#
# * Work with **1D and 2D data structures**
# * Explore and manipulate datasets
# * Select and filter specific data
# * Manage DataFrame columns and indexes
# * Read and write external data files like **CSV** and **JSON**
#
# This foundation is essential for advancing into:
# 📈 Data Analysis • 🤖 Machine Learning • 📊 Data Visualization • 🧠 AI & Data Science
#
# ---
#
# # 💖 Support
#
# If you found this notebook helpful, consider:
#
# * ⭐ Upvoting the notebook
# * 🍴 Forking it for practice
# * 🐼 Sharing it with other learners
# * 💬 Giving feedback or suggestions
#
# Keep practicing — real mastery in Pandas comes from building projects and analyzing real datasets. 🚀
#
# ---
